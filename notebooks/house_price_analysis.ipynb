# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('../data/housing.csv')

print(data.head())
print(data.describe())

sns.pairplot(data)
plt.show()

sns.heatmap(data.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.show()
# Out:
#    Area  Bedrooms  Bathrooms  Location    Price
# 0  1200         2          2     Urban  4500000
# 1  1500         3          2     Urban  6000000
# 2   800         2          1  Suburban  3000000
# 3  2000         4          3     Urban  9000000
# 4  1000         2          1     Rural  2000000
#               Area   Bedrooms  Bathrooms         Price
# count    32.000000  32.000000  32.000000  3.200000e+01
# mean   2775.000000   5.625000   4.750000  1.211562e+07
# std    1448.246994   3.414863   3.302003  7.530073e+06
# min     800.000000   1.000000   1.000000  1.500000e+06
# 25%    1575.000000   3.000000   2.000000  5.875000e+06
# 50%    2400.000000   4.500000   4.000000  1.050000e+07
# 75%    3950.000000   8.250000   7.250000  1.825000e+07
# max    5500.000000  12.000000  11.000000  2.600000e+07
