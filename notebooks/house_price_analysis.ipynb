# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('../data/housing.csv')

print(data.head())
print(data.describe())

sns.pairplot(data)
plt.show()

sns.heatmap(data.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.show()
# Out:
#    Area  Bedrooms  Bathrooms  Location    Price
# 0  1200         2          2     Urban  4500000
# 1  1500         3          2     Urban  6000000
# 2   800         2          1  Suburban  3000000
# 3  2000         4          3     Urban  9000000
# 4  1000         2          1     Rural  2000000
#               Area  Bedrooms  Bathrooms         Price
# count     6.000000  6.000000   6.000000  6.000000e+00
# mean   1383.333333  2.666667   1.833333  5.250000e+06
# std     466.547604  0.816497   0.752773  2.602883e+06
# min     800.000000  2.000000   1.000000  2.000000e+06
# 25%    1050.000000  2.000000   1.250000  3.375000e+06
# 50%    1350.000000  2.500000   2.000000  5.250000e+06
# 75%    1725.000000  3.000000   2.000000  6.750000e+06
# max    2000.000000  4.000000   3.000000  9.000000e+06
